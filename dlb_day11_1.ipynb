# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
df = pd.read_csv('/content/drive/MyDrive/deep_learning_bootcamp/day11/NSE-TATAGLOBAL.csv')
df.shape
# Out:
# (2035, 8)
